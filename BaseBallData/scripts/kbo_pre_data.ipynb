# %%
import requests
import json

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,zh-CN;q=0.8,zh;q=0.7,en-US;q=0.6,en;q=0.5,ja;q=0.4',
    'origin': 'https://m.sports.naver.com',
    'priority': 'u=1, i',
    'referer': 'https://m.sports.naver.com/game/20260404LGWO02026/lineup',
    'sec-ch-ua': '"Chromium";v="146", "Not-A.Brand";v="24", "Google Chrome";v="146"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/146.0.0.0 Safari/537.36',
    'x-sports-backend': 'kotlin',
}

pre_response = requests.get('https://api-gw.sports.naver.com/schedule/games/20260404LGWO02026/preview', headers=headers)
pre_data = pre_response.json()['result']['previewData']

# 원정팀 변수(라인업목록 - preview)
away_pre_data = pre_data['awayTeamLineUp']['fullLineUp']
# 원정팀 투수(라인업목록 - preview)
away_pre_pitcher = away_pre_data[0]['playerName']
away_pre_pit_pcode = away_pre_data[0]['playerCode']
# 원정팀 타자(라인업목록 - preview - 뜨기 전에는 인덱스 1~9가 조회되지 않음)
for i in range(1,10):
    away_pre_bat_order = away_pre_data[i]['batorder']
    away_pre_batters = away_pre_data[i]['playerName']
    away_pre_bat_pcode = away_pre_data[i]['playerCode']

# 홈팀 변수(라인업목록 - preview)
home_pre_data = pre_data['homeTeamLineUp']['fullLineUp']
# 홈팀 투수(라인업목록 - preview)
home_pre_pitcher = home_pre_data[0]['playerName']
home_pre_pit_pcode = home_pre_data[0]['playerCode']
# 홈팀 타자(라인업목록 - preview - 뜨기 전에는 인덱스 1~9가 조회되지 않음)
for i in range(1,10):
    home_pre_bat_order = home_pre_data[i]['batorder']
    home_pre_batters = home_pre_data[i]['playerName']
    home_pre_bat_pcode = home_pre_data[i]['playerCode']

    print(f"{away_pre_bat_order}번타자" ,away_pre_batters,away_pre_bat_pcode)
# Out:
# 9번타자 박해민 62415
# 9번타자 박해민 62415
# 9번타자 박해민 62415
# 9번타자 박해민 62415
# 9번타자 박해민 62415
# 9번타자 박해민 62415
# 9번타자 박해민 62415
# 9번타자 박해민 62415
# 9번타자 박해민 62415
